# %% [markdown]
# # Exercícios
#
# ### Download dos CSVs
#
# - Faça o download dos arquivos ps4_sales.csv e xbox_one_sales.csv no drive da turma.
#
# ### Após o Download
#
# - Crie um notebook para cada um desses dados.
#  - Ou Seja, 1 notebook chamado PS4 e outro chamado Xbox
#
# ### Na sequência
#
# - Faça o import das libs: Pandas, Numpy, Matplotlib.pyplot e Seaborn
# - Faça a leitura dos arquivos
# - Faça a análise inicial que sempre fazemos em aula
#     - Utilize os comandos info, head(15), describe, shape

# %%
# Importando as Libs
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
plt.rcParams['figure.figsize'] = [12,8]

# %%
# Fazendo a leitura do Conjunto de Dados
PS4 = pd.read_csv('ps4_sales.csv')

# %%
XONE = pd.read_csv('xbox_one_sales.csv')

# %%
# Pegando uma amostra dos dados que possuímos no CSV
PS4.head(20)
# Out:
#                               Game    Year             Genre  \
# 0               Grand Theft Auto V  2014.0            Action
# 1        Call of Duty: Black Ops 3  2015.0           Shooter
# 2            Red Dead Redemption 2  2018.0  Action-Adventure
# 3               Call of Duty: WWII  2017.0           Shooter
# 4                          FIFA 18  2017.0            Sports
# 5                          FIFA 17  2016.0            Sports
# 6                  Uncharted (PS4)  2016.0            Action
# 7                 Spider-Man (PS4)  2018.0  Action-Adventure
# 8   Call of Duty: Infinite Warfare  2016.0           Shooter
# 9                        Fallout 4  2015.0      Role-Playing
# 10                         FIFA 16  2015.0            Sports
# 11      Star Wars Battlefront 2015  2015.0           Shooter
# 12  Call of Duty: Advanced Warfare  2014.0           Shooter
# 13                   Battlefield 1  2016.0           Shooter
# ...

# %%
# Salvando o DataFrame para Excel - IDEAL
PS4.to_excel('PS4_SALESteste.xlsx')

# %%
# Pegando uma amostra dos dados que possuímos no CSV
XONE.head(20)
# Out:
#     Pos                               Game    Year             Genre  \
# 0     1                 Grand Theft Auto V  2014.0            Action
# 1     2          Call of Duty: Black Ops 3  2015.0           Shooter
# 2     3                 Call of Duty: WWII  2017.0           Shooter
# 3     4              Red Dead Redemption 2  2018.0  Action-Adventure
# 4     5                          MineCraft  2014.0              Misc
# 5     6     Call of Duty: Advanced Warfare  2014.0           Shooter
# 6     7                      Battlefield 1  2016.0           Shooter
# 7     8                          Fallout 4  2015.0      Role-Playing
# 8     9                  Halo 5: Guardians  2015.0           Shooter
# 9    10     Call of Duty: Infinite Warfare  2016.0           Shooter
# 10   11       Star Wars Battlefront (2015)  2015.0           Shooter
# 11   12                    Forza Horizon 3  2016.0            Racing
# 12   13                            FIFA 17  2016.0            Sports
# ...

# %%
# Obtendo informações básicas do arquivo
PS4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1034 entries, 0 to 1033
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Game           1034 non-null   object
#  1   Year           825 non-null    float64
#  2   Genre          1034 non-null   object
#  3   Publisher      825 non-null    object
#  4   North America  1034 non-null   float64
#  5   Europe         1034 non-null   float64
#  6   Japan          1034 non-null   float64
#  7   Rest of World  1034 non-null   float64
#  8   Global         1034 non-null   float64
# dtypes: float64(6), object(3)
# memory usage: 72.8+ KB

# %%
# Obtendo informações básicas do arquivo
XONE.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 613 entries, 0 to 612
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Pos            613 non-null    int64
#  1   Game           613 non-null    object
#  2   Year           505 non-null    float64
#  3   Genre          613 non-null    object
#  4   Publisher      505 non-null    object
#  5   North America  613 non-null    float64
#  6   Europe         613 non-null    float64
#  7   Japan          613 non-null    float64
#  8   Rest of World  613 non-null    float64
#  9   Global         613 non-null    float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 48.0+ KB

# %%
# Mais uma forma de obter e saber se temos informações faltantes
PS4.describe()
# Out:
#               Year  North America       Europe        Japan  Rest of World  \
# count   825.000000    1034.000000  1034.000000  1034.000000    1034.000000
# mean   2015.966061       0.204613     0.248714     0.033636       0.089014
# std       1.298360       0.563471     0.785491     0.108344       0.249410
# min    2013.000000       0.000000     0.000000     0.000000       0.000000
# 25%    2015.000000       0.000000     0.000000     0.000000       0.000000
# 50%    2016.000000       0.020000     0.000000     0.000000       0.010000
# 75%    2017.000000       0.120000     0.130000     0.030000       0.050000
# max    2020.000000       6.180000     9.710000     2.170000       3.020000
#
#             Global
# count  1034.000000
# mean      0.576054
# std       1.583534
# min       0.000000
# 25%       0.000000
# 50%       0.060000
# 75%       0.357500
# max      19.390000

# %%
# Mais uma forma de obter e saber se temos informações faltantes
XONE.describe()
# Out:
#               Pos         Year  North America      Europe       Japan  \
# count  613.000000   505.000000     613.000000  613.000000  613.000000
# mean   307.000000  2015.821782       0.265628    0.132447    0.000832
# std    177.102136     1.382975       0.594940    0.335311    0.004216
# min      1.000000  2013.000000       0.000000    0.000000    0.000000
# 25%    154.000000  2015.000000       0.000000    0.000000    0.000000
# 50%    307.000000  2016.000000       0.050000    0.000000    0.000000
# 75%    460.000000  2017.000000       0.240000    0.100000    0.000000
# max    613.000000  2020.000000       4.700000    3.250000    0.040000
#
#        Rest of World      Global
# count     613.000000  613.000000
# mean        0.039951    0.438874
# std         0.089343    0.983147
# min         0.000000    0.000000
# 25%         0.000000    0.000000
# 50%         0.010000    0.060000
# 75%         0.030000    0.380000
# max         0.760000    8.720000

# %%
# Verificando campos nulos, ou seja, com informações faltantes
PS4.isnull()

# False = informação existente
# True = informação faltante, ou nula.
# Out:
#        Game   Year  Genre  Publisher  North America  Europe  Japan  \
# 0     False  False  False      False          False   False  False
# 1     False  False  False      False          False   False  False
# 2     False  False  False      False          False   False  False
# 3     False  False  False      False          False   False  False
# 4     False  False  False      False          False   False  False
# ...     ...    ...    ...        ...            ...     ...    ...
# 1029  False   True  False       True          False   False  False
# 1030  False  False  False      False          False   False  False
# 1031  False   True  False       True          False   False  False
# 1032  False   True  False       True          False   False  False
# 1033  False   True  False       True          False   False  False
#
#       Rest of World  Global
# 0             False   False
# 1             False   False
# 2             False   False
# 3             False   False
# ...

# %%
# Verificando campos nulos, ou seja, com informações faltantes
XONE.isnull()

# False = informação existente
# True = informação faltante, ou nula.
# Out:
#        Pos   Game   Year  Genre  Publisher  North America  Europe  Japan  \
# 0    False  False  False  False      False          False   False  False
# 1    False  False  False  False      False          False   False  False
# 2    False  False  False  False      False          False   False  False
# 3    False  False  False  False      False          False   False  False
# 4    False  False  False  False      False          False   False  False
# ..     ...    ...    ...    ...        ...            ...     ...    ...
# 608  False  False  False  False      False          False   False  False
# 609  False  False  False  False      False          False   False  False
# 610  False  False  False  False      False          False   False  False
# 611  False  False  False  False      False          False   False  False
# 612  False  False  False  False      False          False   False  False
#
#      Rest of World  Global
# 0            False   False
# 1            False   False
# ...

# %%
# Para saber o formato(SHAPE) do arquivo
# Temos duas formas
# Essa...
print(XONE.shape)
# Out:
# (613, 10)

# %%
# Para saber o formato(SHAPE) do arquivo
# Temos duas formas
# Essa...
print(PS4.shape)
# Out:
# (1034, 9)

# %%
# E essa...
PS4.shape
# Out:
# (1034, 9)

# %%
XONE.shape
# Out:
# (613, 10)

# %%
# Outra forma de VERIFICAR SE temos informações faltantes
PS4.apply(lambda x: sum(x.isnull()), axis = 0)
# Out:
# Game               0
# Year             209
# Genre              0
# Publisher        209
# North America      0
# Europe             0
# Japan              0
# Rest of World      0
# Global             0
# dtype: int64

# %%
# Outra forma de VERIFICAR SE temos informações faltantes
XONE.apply(lambda x: sum(x.isnull()), axis = 0)
# Out:
# Pos                0
# Game               0
# Year             108
# Genre              0
# Publisher        108
# North America      0
# Europe             0
# Japan              0
# Rest of World      0
# Global             0
# dtype: int64

# %%
# Contando a QTD de games 
PS4['Genre'].value_counts()
# Out:
# Action              258
# Role-Playing        123
# Misc                123
# Adventure            97
# Shooter              89
# Sports               71
# Racing               48
# Platform             46
# Action-Adventure     40
# Fighting             35
# Strategy             28
# Simulation           23
# Music                19
# Puzzle               16
# MMO                   8
# Visual Novel          8
# Party                 2
# Name: Genre, dtype: int64

# %%
# Contando a QTD de games 
XONE['Game'].value_counts()
# Out:
# Biomutant                             2
# INSIDE / LIMBO Double Pack            1
# Assassin's Creed Chronicles: China    1
# NASCAR Heat Evolution                 1
# WRC 6                                 1
#                                      ..
# Red Dead Redemption 2                 1
# The Binding of Isaac: Rebirth         1
# de Blob                               1
# Destiny: The Taken King               1
# Dishonored                            1
# Name: Game, Length: 612, dtype: int64

# %%
print(PS4['Genre'].value_counts()[0])
# Out:
# 258

# %%
print('Action Games:', PS4['Genre'].value_counts()[0])
print('Misc Games:', PS4['Genre'].value_counts()[2])
# Out:
# Action Games: 258
# Misc Games: 123

# %%
PS4['Year'].value_counts()
# Out:
# 2017.0    254
# 2016.0    222
# 2015.0    172
# 2014.0     98
# 2018.0     39
# 2013.0     20
# 2019.0     12
# 2020.0      8
# Name: Year, dtype: int64

# %%
empresa = PS4['Publisher'].value_counts()

# %%
PS4['Publisher'].value_counts()
# Out:
# Namco Bandai Games                56
# Sony Interactive Entertainment    47
# Ubisoft                           45
# Square Enix                       40
# Tecmo Koei                        37
#                                   ..
# Perp Games                         1
# Taleworlds                         1
# Hello Games                        1
# Games Workshop                     1
# Funbox Media                       1
# Name: Publisher, Length: 152, dtype: int64

# %%
PS4['Year'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
plt.subplots(figsize=(20,10))
PS4['Genre'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
generoAno = pd.crosstab(PS4['Year'],PS4['Genre'])

generoAno.plot(kind='bar', stacked = True, cmap = 'RdYlGn')
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
generoAno.plot(figsize=(16,8), cmap = 'turbo')
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
print('Entrada - Rock & Code Party')

ano_atual = 2021
ano_nasc = int(input())

idade = ano_atual - ano_nasc

if idade >= 18:
    print('Entrada permitida.')
elif idade > 14:
    print('Entrada permitida desde que acompanhado(a).')
else:
    print('Entrada proibida.')
# Out:
# Entrada - Rock & Code Party
# 2015
# Entrada proibida.
